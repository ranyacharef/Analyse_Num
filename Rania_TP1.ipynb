# %% [markdown]
# # TP1

# %% [markdown]
# ## Exercice 1:
# On considère le polynôme  𝑝(𝑥)=(𝑥−1)6 .
#
# En développant, on peut écrire ce même polynôme sous la forme  𝑓(𝑥)=𝑥6−6𝑥5+15𝑥4−20𝑥3+15𝑥2−6𝑥+1.
# 1) Avec Matlab évaluer  𝑝(𝑥)  et  𝑓(𝑥)  pour  𝑥  allant de  .998  à  1.002  en choisissant des pas de  .0001 .

# %%
def p(x) :
    """"définir la fonction 𝑝(𝑥)=(𝑥−1)6 """
    return (x-1)**6
def f(x) :
    """"définir la fonction  𝑓(𝑥)=𝑥6−6𝑥5+15𝑥4−20𝑥3+15𝑥2−6𝑥+1"""
    return x**6-6*x**5+15*x**4-20*x**3+15*x**2-6*x+1

# %%
import numpy as np

for i in np.arange(0.998,1.002,0.0001):
    print("-f(",i,")=",f(i))
    print("-p(",i,")=",p(i))
# Out:
# -f( 0.998 )= 1.7763568394002505e-15
# -p( 0.998 )= 6.400000000000034e-17
# -f( 0.9981 )= 1.7763568394002505e-15
# -p( 0.9981 )= 4.70458810000019e-17
# -f( 0.9982 )= 0.0
# -p( 0.9982 )= 3.40122240000027e-17
# -f( 0.9983 )= -2.6645352591003757e-15
# -p( 0.9983 )= 2.4137569000002966e-17
# -f( 0.9984 )= 1.7763568394002505e-15
# -p( 0.9984 )= 1.6777216000002883e-17
# -f( 0.9984999999999999 )= 0.0
# -p( 0.9984999999999999 )= 1.139062500000259e-17
# -f( 0.9985999999999999 )= -1.7763568394002505e-15
# -p( 0.9985999999999999 )= 7.52953600000219e-18
# -f( 0.9986999999999999 )= 8.881784197001252e-16
# -p( 0.9986999999999999 )= 4.826809000001757e-18
# -f( 0.9987999999999999 )= 1.7763568394002505e-15
# -p( 0.9987999999999999 )= 2.985984000001342e-18
# -f( 0.9988999999999999 )= -3.552713678800501e-15
# -p( 0.9988999999999999 )= 1.771561000000975e-18
# -f( 0.9989999999999999 )= 0.0
# -p( 0.9989999999999999 )= 1.0000000000006715e-18
# -f( 0.9990999999999999 )= -2.6645352591003757e-15
# ...

# %% [markdown]
#  2) Faire un graphique de  𝑓(𝑥)  et  𝑝(𝑥) . Commenter.

# %%
import numpy as np
import matplotlib.pyplot as plt 
#Cf ,Cp = plt.subplots()
x=np.linspace(0.998,1.002,40)
plt.plot(x,p(x),label='p(x)')
plt.plot(x,f(x),label='f(x)')
plt.title('solution dans [0.998,1.002]')
plt.legend()
plt.show()

# %% [markdown]
# ## EXERCICE 2:
# On considère l'équation :
# 𝑓(𝑥)=𝑥3+𝑥2−3𝑥−3=0
#
# 1) Dessiner la courbe de  𝑓  dans l'intervalle  [−2;2] , puis trouver des intervalles convenables pour appliquer la méthode de >bisection.
#
# 2) Utiliser un programme dicho.m qui permettra de trouver les solutions de l'équation  𝑓(𝑥)=0  avec  𝑒𝑝𝑠=0.001 .
#
# 3) Modifier le programme dicho.m pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à  𝑒𝑝𝑠  près.

# %% [markdown]
# correction d'exercice 2 :
# 1)

# %%
import numpy as np
import matplotlib.pyplot as plt 
x=np.linspace(-2,2,40)
g=lambda x: x**3+x**2-3*x-3
plt.title('solution dans [-2,2]')
plt.plot(x,g(x),label='f(x)')
plt.legend()
plt.show()

# %% [markdown]
# Daprés le graph de  𝑓  il existe 3 solutions :
# 𝛼_1 ∈]−2;−1.5[
# 𝛼_2∈]−1.5;−0.5[
# 𝛼_3∈]1.5;2[

# %% [markdown]
# 2)

# %%
def dicho(a,b,g,eps):
    '''version itérative '''
    m=(a+b)/2
    err=abs(b-a)
    while err>eps :
        if g(m)==0 :
            break
        elif g(a)*g(m)<0 :
            b=m
        else: a=m
        m=(a+b)/2
        err=abs(b-a)
    return m

# %%
print(dicho(-2,-1.5,g,0.001))
# Out:
# -1.73193359375

# %% [markdown]
# 3)

# %%
def dichow(a,b,f,eps):
    """version tant que qui renvoila solution avec le nombre d'''itération """
    m=(a+b)/2
    err=abs(b-a)
    n=0
    while err>eps :
        n+=1
        if f(m)==0 :
            break
        elif f(a)*f(m)<0 :
            b=m
        else: a=m
        m=(a+b)/2
        err=abs(b-a)
    return m,n

# %%
import numpy as np
a=-1.5
b=-0.5
p=8 # précision à 10 ^-8 prés
dichow(a,b,g,10**(-p))
#à 10^-8
# Out:
# (-1.0, 1)

# %%
interval=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for u in interval:
    print(dichow(u[0],u[1],g,10**(-3)))
# Out:
# (-1.73193359375, 9)
# (-1.0, 1)
# (1.73193359375, 9)

# %% [markdown]
# Le nombre d'itération N nécéssaire à la méthode de la dichotomie pour trouver  𝛼  à  10−𝑝  prés
#
#                     𝑁≥𝐸((ln(𝑏−𝑎)+𝑝ln(10))/ln(2))+1

# %%
## Ecrire une fonction qui permet de renvoyer le nombre d'itération nécessaire à la méthode de dichotomie pour calculer
## la solution à 10^-p près
import math 
import numpy as np
#def ND(a,b,p):
#    s=np.ceil(math.log(b-a)+p*math.log(10)/math.log(2))   
#    return s
ND=lambda a,b,p: np.floor(math.log(b-a)+p*math.log(10)/math.log(2))

# %%
a=-2
b=-1.5
ND(a,b,5)
# Out:
# 15.0

# %%
#alpha 1
dichow(-2,-1.5,g,10**(-5))
#à 10^-8
# Out:
# (-1.7320518493652344, 16)

# %%
#alpha 2
dichow(-1.51,-0.5,g,10**(-5))
#à 10^-8
# Out:
# (-1.0000028610229492, 17)

# %%
#alpha 3
dichow(1.5,2,g,10**(-5))
#à 10^-8
# Out:
# (1.7320518493652344, 16)

# %% [markdown]
# ## Méthode graphique pour la recherche de la solution

# %%
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+x**2-3*x-3

t=np.linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# ## EXERCICE 3:
# >On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[1;2]$, puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).
# >
# >2) Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:
# >
# >a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
# >
# >b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# >
# >c) $g_3(x)=x-x^3-4x^2+10=x$.
# >
# >3) Ecrire puis appliquer  une fonction Matlab que l'on appellera  `pointfixe.m` aux trois schémas précédents en prenant >`x0=1.5;eps=0.001`.
# >
# >4) Quelle est la fonction (parmi $g_1, g_2$ et $g_3$) qui donne la convergence la plus rapide?

# %% [markdown]
# 1)

# %%
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+4*x**2-10

t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# #### 2) Justification théorique pour la fonction g1

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
#
# a) $g(x)=\frac{1}{2}\sqrt{10-x^3}=x$.

# %% [markdown]
#  $$x^3+4x^2-10=0$$
#
#  $$4x^2=10-x^3$$
#
#  $$2x=\sqrt{10-x^3}$$
#
#  $$x=\frac{1}{2}\sqrt{10-x^3}$$
#
# Donc $ f(x)=g(x)$

# %% [markdown]
# ## Calcul symboliquede la dérivée

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g1=lambda x: 1/2*sqrt(10-x**3)

# %%
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# ## Justification théoriques pour g2 et g3

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# b) $g(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2=10$$
# $$x^2(x+4)=10$$
# $$x^2=\frac{10}{x+4}$$
# $$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$
#
# c) $g(x)=x-x^3-4x^2+10=x$
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2-10+x-x=0$$
# $$x^3-4x^2+x-x=10$$
# $$x^3-4x^2+x=x+10$$
# $$4x^2+x=x-x^3+10$$
# $$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# ## Etudier théoriquement la convergences de g2 et g3

# %%
import math
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*math.sqrt(10-x**3)
g2=lambda x: math.sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe(g,x0,eps,nmax):
    zero=x0
    for i in range(nmax):
        x=zero 
        zero=g(x)
        erreur=abs(zero-x)
        if erreur<eps: 
            return x, erreur
    pass

    print('pas de convergence ')

# %% [markdown]
# ### quelle est la fonction qui donne la convergence la plus rapide ??

# %%
print(ptfixe(g1,1.5,0.001,50))
# Out:
# (1.364878217193677, 0.0005318439762798111)

# %%
print(ptfixe(g2,1.5,0.001,50))
# Out:
# (1.364957015402487, 0.0003077327109550776)

# %% [markdown]
# 4)

# %%
import math
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*math.sqrt(10-x**3)
g2=lambda x: math.sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe1(g,x0,eps,nmax):
    zero=x0
    for i in range(nmax):
        x=zero 
        zero=g(x)
        erreur=abs(zero-x)
        if erreur<eps: 
            return x, erreur , i 
    pass

    print('pas de convergence avec le nombre d''iteration indique')

# %%
print(ptfixe1(g2,1.5,0.001,50))
# Out:
# (1.364957015402487, 0.0003077327109550776, 3)

# %%
print(ptfixe1(g1,1.5,0.001,50))
# Out:
# (1.364878217193677, 0.0005318439762798111, 9)

# %% [markdown]
# # EXERCICE 4:
# >1) On considère la fonction $f(x)=e^{-x}-x$. Ecrire puis appliquer  une fonction Matlab que l'on appellera `newton.m` à la >fonction $f$, en prenant $x0=0$, $eps=0.001$ .
# >
# >2) Montrer que l'équation $f(x)=0$ admet une solution unique que l'on peut obtenir en utilisant la méthode de Newton à partir >de $x0=1$.

# %% [markdown]
# 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
def newton(a,eps):
    x1=a
    x2=x1-f(x1)/fprime(x1)
    while abs(x1-x2)>eps :
        x1=x2
        x2=x1-f(x1)/fprime(x1)
    sol=x2
    return (sol)

# %%
f=lambda x: np.exp(-x)-x
fprime= lambda x: -np.exp(-x)-1
t=np.linspace(0,1,100);
plt.plot(t,f(t))
plt.show()
print ("sol= ",newton(0,0.001))
# Out:
# sol=  0.5671431650348622

# %% [markdown]
# 2)

# %%
print('sol = ',newton(1,0.001))
# Out:
# sol =  0.567143285989123
